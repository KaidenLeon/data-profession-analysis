# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20170925-1).
# fonts-nanum-coding is already the newest version (2.5-1).
# fonts-nanum-eco is already the newest version (1.000-6).
# fonts-nanum-extra is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mp1 = pd.read_csv('/content/drive/MyDrive/4조  일반/2021_data-pro v.02.csv', encoding='utf8')

# %%
mp1.columns
# Out:
# Index(['index', 'Job_Title', 'Queried_Salary', 'Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer provided', 'Lower Salary', 'Upper Salary',
#        'Avg Salary(K)', 'company_txt', 'Age', 'Python', 'R', 'scala', 'spark',
#        'aws', 'excel', 'sql', 'sas', 'ML', 'hadoop', 'tableau', 'flink',
#        'mongo', 'google_an', 'Job_Type', 'seniority_by_title', 'Job Location',
#        'AL', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'IA', 'ID', 'IL',
#        'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'MI', 'MN', 'MO', 'NC', 'NE', 'NJ',
#        'NM', 'NY', 'OH', 'OR', 'PA', 'RI', 'SC', 'TN', 'TX', 'UT', 'VA', 'WA',
#        'WI', 'Industry.1', '항공우주공학', '농업', '금융서비스', 'IT산업', '건설', '비즈니스', '교육',
#        '에너지', '정부', '의료', '제조', '보험', '방송', '부동산', '운송', 'Degree', 'm', 'p',
#        'both'],
#       dtype='object')

# %%
mp2 = pd.read_csv('/content/drive/MyDrive/4조  일반/indeed_job_dataset_ver03.csv', encoding='utf8')

# %%
mp2.columns
# Out:
# Index(['index', 'Job_Title', 'Queried_Salary', 'Job_Type', 'Skill',
#        'No_of_Skills', 'Company', 'Description', 'Location', 'Company_Revenue',
#        ...
#        'Consulting and Business Services', 'Internet and Software',
#        'Banks and Financial Services', 'Health Care', 'Insurance',
#        'Other_industries', 'Degree.1', 'm', 'p', 'both'],
#       dtype='object', length=101)

# %%
mp1['Degree'].unique()
# Out:
# array(['both', 'M', '0', 'P'], dtype=object)

# %%
mp2['Degree'].unique()
# Out:
# array(['M', 'P', 'na', 'both'], dtype=object)

# %%
#2021
print(sum(mp1['m']==1))
print(sum(mp1['p']==1))
print(sum(mp1['both']==1))
# Out:
# 203
# 49
# 19

# %%
#2018
print(sum(mp2['m']==1))
print(sum(mp2['p']==1))
print(sum(mp2['both']==1))
# Out:
# 960
# 1033
# 194

# %%
#전체 직군별 #제목 : 22 xlabel : 18 ylable : 18 xticks : 15 yticks : 15
fig, axes = plt.subplots(1, 2,figsize=(20, 15))
labels1=['석사','박사']
sizes1 =[960,1033]
sizes2 =[203,49]

axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('2018')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('2021')

fig.subplots_adjust(wspace=0.0)

# %%
#2018
x1 = np.arange(2)
deg1 = ['석사', '박사']
value1 = [960, 1033]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2021
x2 = np.arange(2)
deg2 = ['석사', '박사']
value2 = [203, 49]
plt.bar(x2, value2, color='r')
plt.xticks(x2, deg2)
plt.show()

# %%
#2018
#DS 석사 372 박사975, DE 석사 253 박사83, DA 석사 335 박사 75
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['석사', '박사']
sizes1 =[372,  975]
sizes2 =[253, 83]
sizes3= [335, 75]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('데이터 과학자')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('데이터 엔지니어')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('데이터 분석가')
fig.subplots_adjust(wspace=0.75)

# %%
#데이터 과학자
x1 = np.arange(2)
deg1 = ['석사', '박사']
value1 = [372,  975]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#데이터 엔지니어
x2 = np.arange(2)
deg2 = ['석사', '박사']
value2 = [253,83]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#데이터 분석가
x3 = np.arange(2)
deg3 = ['석사', '박사']
value3 = [335, 75]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2021
#DS 석사 135 박사 47, DE 석사 35 박사 2, DA 석사 33 박사 0
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['석사', '박사']
sizes1 =[135,  47]
sizes2 =[35, 2]
sizes3= [33, 0]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('데이터 과학자')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('데이터 엔지니어')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('데이터 분석가')
fig.subplots_adjust(wspace=0.75)

# %%
#데이터 과학자
x1 = np.arange(2)
deg1 = ['석사', '박사']
value1 = [135,  47]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#데이터 엔지니어
x2 = np.arange(2)
deg2 = ['석사', '박사']
value2 = [35, 2]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()


#데이터 분석가
x3 = np.arange(2)
deg3 = ['석사', '박사']
value3 = [33, 0]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2018 # 데이터프레임 생성 / 신입: (<80000-99999), 중급 :(100000-139999), 고급: (140000->160000)
salary = mp2.set_index('Queried_Salary')
salary_skill_df= salary.loc[['<80000','80000-99999','100000-119999','120000-139999','140000-159999','>160000'],
          ['Job_Type']]
salary_skill_df
jobtype_groups = salary_skill_df.groupby('Queried_Salary')
job_type_df= jobtype_groups['Job_Type'].value_counts() 
df = pd.DataFrame(job_type_df)
#df.reorder_levels(0,("<80000","80000-99999","100000-119999","120000-139999","140000-159999",">160000"))
df.sort_index(ascending = False)
# Out:
#                                Job_Type
# Queried_Salary Job_Type
# >160000        data_scientist       231
#                data_engineer        104
#                data_analyst          80
# <80000         data_scientist        48
#                data_engineer         27
#                data_analyst         713
# 80000-99999    data_scientist       233
#                data_engineer        125
#                data_analyst         595
# 140000-159999  data_scientist       551
#                data_engineer        275
#                data_analyst          47
# 120000-139999  data_scientist       770
#                data_engineer        452
#                data_analyst          70
# 100000-119999  data_scientist       710
#                data_engineer        396
#                data_analyst         288

# %%
#2018 초급 데이터 과학자 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [281,  42, 88 ]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2018 중급 데이터 과학자 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [1480,256, 415]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2018 고급 데이터 과학자 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [782, 74, 372]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2018 데이터 과학자 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[151,  42, 88 ]
sizes2 =[809,256, 415]
sizes3= [336, 74, 372]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DS')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DS')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DS')
fig.subplots_adjust(wspace=0.75)

# %%
#2018 초급 데이터 엔지니어 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [152,  21, 15 ]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2018 중급 데이터 엔지니어 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [848,161, 47]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2018 고급 데이터 엔지니어 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [379, 71, 21]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2018 데이터 엔지니어 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[116,  21, 15 ]
sizes2 =[640,161, 47]
sizes3= [287, 71, 21]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DE')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DE')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DE')
fig.subplots_adjust(wspace=0.75)

# %%
#2018 초급 데이터 분석가 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [1308,  228, 39 ]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2018 중급 데이터 분석가 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [358,75, 19]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2018 고급 데이터 분석가 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [127, 32, 17]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2018 데이터 분석가 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[1041,  228, 39 ]
sizes2 =[264,75, 19]
sizes3= [78, 32, 17]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DA')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DA')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DA')
fig.subplots_adjust(wspace=0.75)

# %%
base = mp1['Queried_Salary'].str.split('-')
base
# Out:
# 0       [53000, 91000]
# 1      [63000, 112000]
# 2       [80000, 90000]
# 3       [56000, 97000]
# 4      [86000, 143000]
#             ...
# 594    [37000, 100000]
# 595    [62000, 113000]
# 596    [86000, 137000]
# 597    [72000, 133000]
# 598    [95000, 160000]
# Name: Queried_Salary, Length: 599, dtype: object

# %%
entry = []
mid = []
senior = []
for i in range(len(base)):
    if int(base[i][1]) < 80000:
        mp1.iloc[i, 2] = '<80000'
    elif int(base[i][1]) < 99999:
        mp1.iloc[i, 2] = '80000-99999'
    elif int(base[i][1]) < 119999:
        mp1.iloc[i, 2] = '100000-119999'
    elif int(base[i][1]) < 139999:
        mp1.iloc[i, 2] = '120000-139999'
    elif int(base[i][1]) < 159999:
        mp1.iloc[i, 2] = '140000-159999'
    elif int(base[i][1]) > 160000:
        mp1.iloc[i, 2] = '>160000'

# %%
#2021 # 데이터프레임 생성 / 신입: (<80000-99999), 중급 :(100000-139999), 고급: (140000->160000)
salary = mp1.set_index('Queried_Salary')
salary_skill_df= salary.loc[['<80000','80000-99999','100000-119999','120000-139999','140000-159999','>160000'],
          ['Job_Type']]
salary_skill_df
jobtype_groups = salary_skill_df.groupby('Queried_Salary')
job_type_df= jobtype_groups['Job_Type'].value_counts()
df = pd.DataFrame(job_type_df)
#df.reorder_levels(0,("<80000","80000-99999","100000-119999","120000-139999","140000-159999",">160000"))
df.sort_index(ascending = False)
# Out:
#                                Job_Type
# Queried_Salary Job_Type
# >160000        data engineer         20
#                Data Scientist       116
#                Data Analyst           3
# <80000         data engineer          2
#                Data Scientist         8
#                Data Analyst          59
# 80000-99999    data engineer         13
#                Data Scientist        44
#                Data Analyst          29
# 140000-159999  data engineer         28
#                Data Scientist        59
#                Data Analyst           3
# 120000-139999  data engineer         28
#                Data Scientist        73
#                Data Analyst           7
# 100000-119999  data engineer         28
#                Data Scientist        56
#                Data Analyst          13

# %%
#2021 초급 데이터 과학자 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [131,  44, 17 ]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2021 중급 데이터 과학자 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [142,67, 21]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2021 고급 데이터 과학자 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [92, 24, 28]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2021 데이터 과학자 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[70,  44, 17 ]
sizes2 =[54,67, 21]
sizes3= [40, 24, 28]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DS')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DS')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DS')
fig.subplots_adjust(wspace=0.75)

# %%
#2021 초급 데이터 엔지니어 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [59,20, 1]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2021 중급 데이터 엔지니어 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [47, 10, 0]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2021 고급 데이터 엔지니어 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [13, 5, 1]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2021 데이터 엔지니어 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[38,20, 1]
sizes2 =[37, 10, 0]
sizes3= [7, 5, 1]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DE')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DE')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DE')
fig.subplots_adjust(wspace=0.75)

# %%
#2021 초급 데이터 분석가 연봉 및 학력
x1 = np.arange(3)
deg1 = ['초급연봉자','석사', '박사']
value1 = [102,  29, 0 ]
plt.bar(x1, value1, color='b')
plt.xticks(x1, deg1)
plt.show()

#2021 중급 데이터 분석가 연봉 및 학력
x2 = np.arange(3)
deg2 = ['중급연봉자','석사', '박사']
value2 = [11,7, 0]
plt.bar(x2, value2, color='y')
plt.xticks(x2, deg2)
plt.show()

#2021 고급 데이터 분석가 연봉 및 학력
x3 = np.arange(3)
deg3 = ['고급연봉자','석사', '박사']
value3 = [1, 0, 0]
plt.bar(x3, value3, color='r')
plt.xticks(x3, deg3)
plt.show()

# %%
#2021 데이터 분석가 연봉별 
fig, axes = plt.subplots(1, 3,figsize=(20, 20))
labels1=['나머지','석사', '박사']
sizes1 =[73,  29, 0 ]
sizes2 =[4,7, 0]
sizes3= [1, 0, 0]
axes[0].pie(sizes1, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85, startangle=140)
axes[0].set_title('초급DA')
axes[1].pie(sizes2, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                   shadow=True,pctdistance=0.85,startangle=140 )
axes[1].set_title('중급DA')
axes[2].pie(sizes3, labels=labels1,autopct='%.0f%%',textprops={'fontsize': 15},
                            shadow=True,pctdistance=0.85,startangle=140 )
axes[2].set_title('고급DA')
fig.subplots_adjust(wspace=0.75)
